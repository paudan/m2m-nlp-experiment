# %%
import os
import spacy
from spacy import displacy
from spacy.symbols import nsubj, VERB

# %%
os.chdir('..')
nlp = spacy.load("spacy/en_core_web_lg/en_core_web_lg/en_core_web_lg")

# %%
doc = nlp("Initiate, produce, prepare and test software")
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_, token.conjuncts)
displacy.render(doc, style='dep')
# Out:
# Initiate ROOT Initiate VERB (produce, software, prepare)
# , punct Initiate VERB ()
# produce conj Initiate VERB (Initiate, software, prepare)
# , punct produce VERB ()
# prepare conj produce VERB (Initiate, produce, software)
# and cc prepare VERB ()
# test compound software NOUN ()
# software conj Initiate VERB (Initiate, produce, prepare)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2b2650e36edd4a50991320df4b60b40b-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Initiate,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# ...

# %%
doc = nlp("Create specification, gather team and develop software")
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_, token.conjuncts)
displacy.render(doc, style='dep')
# Out:
# Create advcl gather VERB ()
# specification dobj Create VERB ()
# , punct gather VERB ()
# gather ROOT gather VERB (develop,)
# team dobj gather VERB ()
# and cc gather VERB ()
# develop conj gather VERB (gather,)
# software dobj develop VERB ()
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="26bf4a8d7a4c4a078bdd9cabf6c4a5d9-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Create</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
doc = nlp("Implement specification, software and tests")
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_, [child for child in token.children])
displacy.render(doc, style='dep')
# Out:
# Implement ROOT Implement VERB [specification]
# specification dobj Implement VERB [,, software]
# , punct specification NOUN []
# software conj specification NOUN [and, tests]
# and cc software NOUN []
# tests conj software NOUN []
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="28876d0d04a74845b9da72cd68f2fbcc-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Implement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
doc = nlp("Implement specification, produce software, prepare documentation and tests")
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_, token.conjuncts)
displacy.render(doc, style='dep')
# Out:
# Implement ROOT Implement VERB (software, prepare)
# specification dobj Implement VERB ()
# , punct Implement VERB ()
# produce compound software NOUN ()
# software conj Implement VERB (Implement, prepare)
# , punct Implement VERB ()
# prepare conj Implement VERB (Implement, software)
# documentation dobj prepare VERB (tests,)
# and cc documentation NOUN ()
# tests conj documentation NOUN (documentation,)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="dd3b1257fd674cbf8a891978e72d477e-0" class="displacy" width="1450" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Implement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# ...

# %%
doc = nlp("Implement specification, produce software or test items")
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_, [child for child in token.children])
displacy.render(doc, style='dep')
# Out:
# Implement ROOT Implement VERB [specification, ,, produce, items]
# specification dobj Implement VERB []
# , punct Implement VERB []
# produce conj Implement VERB [software]
# software dobj produce VERB [or]
# or cc software NOUN []
# test compound items NOUN []
# items dobj Implement VERB [test]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e5da79afff1a4fb98322ea85201c41d2-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Implement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
doc = nlp("Implement initial specification, required software or test items")
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_, [child for child in token.children])
displacy.render(doc, style='dep')
# Out:
# Implement ROOT Implement VERB [specification, ,, software]
# initial amod specification NOUN []
# specification dobj Implement VERB [initial]
# , punct Implement VERB []
# required amod software NOUN []
# software conj Implement VERB [required, or, items]
# or cc software NOUN []
# test compound items NOUN []
# items conj software NOUN [test]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="76ce6bcc86754190afe69552f18cd9cb-0" class="displacy" width="1450" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Implement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# ...

# %%
doc = nlp("Implement specification, required software or test items")
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_, [child for child in token.children])
displacy.render(doc, style='dep')
# Out:
# Implement ROOT Implement VERB [specification, ,]
# specification dobj Implement VERB []
# , punct Implement VERB []
# required amod software NOUN []
# software ROOT software NOUN [required, or, items]
# or cc software NOUN []
# test compound items NOUN []
# items conj software NOUN [test]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="386a1ca4ad864b48a92c75de12c9a9ca-0" class="displacy" width="1275" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Implement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
doc = nlp("Create specification and develop software, as well as improve tools")
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_, [child for child in token.children])
displacy.render(doc, style='dep')
# Out:
# Create ROOT Create VERB [specification, and, develop]
# specification dobj Create VERB []
# and cc Create VERB []
# develop conj Create VERB [software, ,, as, improve]
# software dobj develop VERB []
# , punct develop VERB []
# as advmod as ADP []
# well advmod as ADP []
# as cc develop VERB [as, well]
# improve conj develop VERB [tools]
# tools dobj improve VERB []
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0909bda7b4ef4127aa39e7a459b3f515-0" class="displacy" width="1800" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Create</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# ...

# %%
doc = nlp("Implement specification, software and tests")
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="08951037c943405395d36974b2ead10c-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Implement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">specification,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
doc = nlp("Write specification, produce software and create tests")
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="549af2f1748844f5a742bf77ae08b53c-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Write</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">specification,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
doc = nlp("Create specification and develop software, start tests, integration and deployment")
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7e33869f8a1a4c1abd26ee68144774f2-0" class="displacy" width="1800" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Create</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">specification</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
doc = nlp("call applicant, ask for completion of data")
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e4025f12a2944103b8fbb6ed56e8d582-0" class="displacy" width="1275" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">call</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">applicant,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
doc = nlp("mark as withdrawn and file")
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0feeabed4c054c29be20f42e776b9727-0" class="displacy" width="925" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">mark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
doc = nlp("Evaluate your personnel and management relationship with the bank")
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="353936229b054912a9306c8323ac4881-0" class="displacy" width="1625" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Evaluate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
# ...

# %%
doc = nlp("Collect Master Record Requests from Data Entry / Deliver Mail from Master Data Entry Staff")
print(list(doc.noun_chunks))
for token in doc:
    print(token.text, token.dep_, token.head.text, token.pos_, token.conjuncts, [child for child in token.children])
displacy.render(doc, style='dep')
# Out:
# [Master Record Requests, Data Entry, Mail, Master Data Entry Staff]
# Collect ROOT Collect VERB () [Requests, /]
# Master compound Requests PROPN () []
# Record compound Requests PROPN () []
# Requests dobj Collect NOUN () [Master, Record, from]
# from prep Requests ADP () [Entry]
# Data compound Entry PROPN () []
# Entry pobj from PROPN () [Data]
# / punct Collect PUNCT () []
# Deliver ROOT Deliver VERB () [Mail, from]
# Mail dobj Deliver PROPN () []
# from prep Deliver ADP () [Staff]
# Master compound Staff PROPN () []
# Data compound Staff PROPN () []
# Entry compound Staff PROPN () []
# Staff pobj from PROPN () [Master, Data, Entry]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2e7cf92c71904d69a9296f7a33cb181a-0" class="displacy" width="2500" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# ...
